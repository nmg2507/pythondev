# %% [markdown]
# ### 12　Pandas の使い方 ノート

# %%
import pandas as pd
df = pd.read_csv("./sample_data/california_housing_train.csv")
print(type(df)) #データタイプを確認。pd.read_csvは、リストやndarrayとは別形式。
# Out:
# <class 'pandas.core.frame.DataFrame'>
